# %% [markdown]
# Nama : Muhammad Fatih Nuril Hadi

# %% [markdown]
# Nim : 20220801411

# %% [markdown]
# UTS Machine Learning

# %% [markdown]
# Essay :

# %% [markdown]
# 1) Jelaskan apa yang dimaksud dengan Machine Learning

# %% [markdown]
# Machine Learning adalah bagian dari bidang kecerdasan buatan yang menggunakan algoritma dan model statistik untuk membantu komputer meningkatkan kemampuannya dalam menyelesaikan tugas tertentu berdasarkan pengalaman. Berbeda dengan pendekatan pemrograman tradisional yang memerlukan instruksi eksplisit, dalam Machine Learning, sistem belajar dari pola-pola dalam data untuk membuat prediksi atau keputusan.

# %% [markdown]
# 2. Berikan contoh penerapan implemetasi dalam kehidupan sehari-hari terkait Machine Learning. Dan jelaskan mengapa membutuhkannya dan manfaatnya

# %% [markdown]
# a. Penerjemahan Bahasa Otomatis: Aplikasi seperti Google Translate menggunakan algoritma pembelajaran mesin untuk menerjemahkan teks dari satu bahasa ke bahasa lain secara otomatis. Ini membantu pengguna yang berinteraksi dengan teks dalam bahasa yang tidak mereka mengerti secara langsung. Contoh ini menunjukkan bagaimana Machine Learning membantu mengatasi hambatan bahasa dan memfasilitasi komunikasi lintas bahasa, yang merupakan kebutuhan penting dalam era globalisasi.

# %% [markdown]
# b. Rekomendasi Personal: Layanan seperti Netflix, Amazon, dan Spotify menggunakan algoritma Machine Learning untuk memberikan rekomendasi tentang film, produk, dan musik berdasarkan preferensi pengguna. Ini meningkatkan pengalaman pengguna dengan membantu mereka menemukan konten yang sesuai dengan minat mereka. Kita membutuhkan hal ini karena dengan jumlah besar konten yang tersedia di platform-platform tersebut, sulit bagi pengguna untuk menavigasi dan menemukan hal yang mereka sukai. Dengan algoritma Machine Learning, platform dapat memberikan rekomendasi yang lebih akurat, memastikan bahwa pengguna memiliki pengalaman yang lebih memuaskan.

# %% [markdown]
# c. Deteksi Penipuan: Lembaga keuangan memanfaatkan Machine Learning untuk mengidentifikasi transaksi penipuan dengan menganalisis pola dan mengenali perilaku yang mencurigakan. Ini penting karena membantu mencegah kerugian finansial dan meningkatkan keamanan. Algoritma Machine Learning yang terus belajar dari data transaksi baru membantu institusi keuangan untuk lebih efektif dalam mendeteksi aktivitas yang mencurigakan, mengurangi risiko kerugian akibat penipuan, dan membangun kepercayaan pelanggan terhadap sistem keuangan.

# %% [markdown]
# 3. Jelaskan macam-macam taxonomi dalam pengerapan Machine Learning

# %% [markdown]
# a. Supervised Learning (Pembelajaran Terawasi) : Model dilatih pada data yang berlabel. Contohnya termasuk klasifikasi (misalnya, deteksi spam email) dan regresi (misalnya, prediksi harga rumah).

# %% [markdown]
# b. Unsupervised Learning (Pembelajaran tak Terawasi) : Model dilatih pada data yang tidak berlabel. Contohnya termasuk pengelompokan (misalnya, segmentasi pelanggan) dan asosiasi (misalnya, analisis keranjang belanja).

# %% [markdown]
# c. Reinforcement Learning (Pembelajaran Penguatan) : Model belajar dengan berinteraksi dengan lingkungan dan menerima umpan balik berupa hadiah atau hukuman. Contohnya termasuk permainan dan pengendalian robotik.

# %% [markdown]
# Studi Kasus :

# %% [markdown]
# 1) Sempurnakan Data Set Universitas Esa Unggul memiliki detail mahasiswa sebagai berikut :
# Ani, Budi, Joni, Jono dan Lono Setiap mahasiswa dating ke kampus mulai dari hari senin sampai
# minggu Untuk melakukan kegiatan kuliah Ani menghabiskan biaya 30000 dikampus setiap datang
# Budi menghabiskan biaya 35000 dikampus setiap datang Joni menghabiskan biaya 20000
# dikampus setiap datang Jono 25000 dan Lono 15000
#
#     ![image.png](attachment:1877202a-296a-41e6-9bfd-854f73678e97.png)
#
#     a) Berapa rata-rata mahasiswa datang pada minggu ini?
#     b) Kapan biaya tertinggi terjadi?
#     c) Hari apa biaya lebih dari 110000?
#     d) Siapa yang paling banyak datang ke kampus?
#     e) Siapa yang datang pada hari minggu?
#     f) Berapa biaya tertinggi dan terendah?
#     g) Berapa frekuensi datang tertinggi dan terendah?

# %%
import pandas as pd

data = {
    'Hari': ['Senin', 'Selasa', 'Rabu', 'Kamis', 'Jumat', 'Sabtu', 'Minggu'],
    'Datang': [2, 3, 4, 1, 1, 5, 2],
    'Biaya': [30000*2, 35000*3, 25000*4, 15000*1, 20000*1, 30000*5, 35000*2],
    'Mahasiswa': ['Ani', 'Budi', 'Jono', 'Lono', 'Joni', 'Ani', 'Budi']
}

df = pd.DataFrame(data)

rata_rata_datang = df['Datang'].mean()

biaya_tertinggi_hari = df.loc[df['Biaya'].idxmax(), 'Hari']
biaya_tertinggi = df['Biaya'].max()

hari_biaya_lebih_110000 = df[df['Biaya'] > 110000]['Hari'].tolist()

mahasiswa_terbanyak = df['Mahasiswa'].value_counts().idxmax()

datang_minggu = df.loc[df['Hari'] == 'Minggu', 'Mahasiswa'].values[0]

biaya_terendah = df['Biaya'].min()

frekuensi_tertinggi = df['Datang'].max()
frekuensi_terendah = df['Datang'].min()

print(f"a) Rata-rata mahasiswa datang pada minggu ini: {rata_rata_datang:.2f}")
print(f"b) Biaya tertinggi terjadi pada hari: {biaya_tertinggi_hari} dengan biaya {biaya_tertinggi}")
print(f"c) Hari dengan biaya lebih dari 110000: {', '.join(hari_biaya_lebih_110000)}")
print(f"d) Mahasiswa yang paling banyak datang ke kampus: {mahasiswa_terbanyak}")
print(f"e) Mahasiswa yang datang pada hari Minggu: {datang_minggu}")
print(f"f) Biaya tertinggi: {biaya_tertinggi}, Biaya terendah: {biaya_terendah}")
print(f"g) Frekuensi datang tertinggi: {frekuensi_tertinggi}, Frekuensi datang terendah: {frekuensi_terendah}")
# Out:
# a) Rata-rata mahasiswa datang pada minggu ini: 2.57
# b) Biaya tertinggi terjadi pada hari: Sabtu dengan biaya 150000
# c) Hari dengan biaya lebih dari 110000: Sabtu
# d) Mahasiswa yang paling banyak datang ke kampus: Ani
# e) Mahasiswa yang datang pada hari Minggu: Budi
# f) Biaya tertinggi: 150000, Biaya terendah: 15000
# g) Frekuensi datang tertinggi: 5, Frekuensi datang terendah: 1

# %% [markdown]
# 2. Lengkapi source code dibawah berikut
# ```
# fakultas <- c("Bisnis", "D3 Perhotelan", "ICT", "Ilmu Komunikasi", "Seni dan Desain")
# jumlah_mahasiswa <- c(260, 28, 284, 465, 735)
# akreditasi <- c("A","A","B","A","A")
# info_mahasiswa <- data.frame(fakultas, jumlah_mahasiswa, akreditasi)
# info_mahasiswa
# gambar <- ggplot(info_mahasiswa, aes(x=fakultas, y=jumlah_mahasiswa, fill=fakultas))
# gambar <- gambar + geom_bar(width=1, stat="identity")
# gambar
# ```
# Sehingga dapat menghasilkan seperti berikut
# ![image.png](attachment:30387835-4c17-4e33-b22d-3f7f4f68295f.png)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
data = {
    'Fakultas': ["Bisnis", "D3 Perhotelan", "ICT", "Ilmu Komunikasi", "Seni dan Desain"],
    'Jumlah_Mahasiswa': [260, 28, 284, 465, 735],
    'Akreditasi': ["A", "A", "B", "A", "A"]
}

df = pd.DataFrame(data)
print(df)
plt.figure(figsize=(10, 6))
plot = sns.barplot(x='Fakultas', y='Jumlah_Mahasiswa', data=df, palette='viridis')
plot.set_title('Jumlah Mahasiswa per Fakultas')
plot.set_xlabel('Fakultas')
plot.set_ylabel('Jumlah Mahasiswa')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
#           Fakultas  Jumlah_Mahasiswa Akreditasi
# 0           Bisnis               260          A
# 1    D3 Perhotelan                28          A
# 2              ICT               284          B
# 3  Ilmu Komunikasi               465          A
# 4  Seni dan Desain               735          A
